# %%
import geocoder
g = geocoder.ip('me')
print(g.latlng)
# Out:
# [-12.0432, -77.0282]

# %%
import pandas as pd
archivo_path = "pruebadino.csv"  # Reemplazar con la ruta real
df = pd.read_csv(archivo_path, delimiter=';')
df['Latitud'] = df['WKT'].str.extract(r'\(([-\d\.]+) [-\d\.]+\)').astype(float)
df['Longitud'] = df['WKT'].str.extract(r'\([-\d\.]+ ([-\d\.]+)\)').astype(float)

# %%
# Out:
#                                    WKT Nombre Grupo Clientes  \
# 0    POINT (-79.02573813 -8.115784505)              Asociado
# 1    POINT (-79.02573813 -8.115784505)              Asociado
# 2    POINT (-79.02573813 -8.115784505)              Asociado
# 3    POINT (-79.02573813 -8.115784505)              Asociado
# 4    POINT (-79.04597338 -8.086050832)              Asociado
# ..                                 ...                   ...
# 311  POINT (-79.01534792 -8.068742299)       Ferrexperto TOP
# 312  POINT (-79.00107387 -8.114591921)       Ferrexperto TOP
# 313  POINT (-79.00107387 -8.114591921)       Ferrexperto TOP
# 314  POINT (-79.00107387 -8.114591921)       Ferrexperto TOP
# 315  POINT (-79.00107387 -8.114591921)       Ferrexperto TOP
#
#                           Nombre Cliente                      Producto  \
# 0    ABELARDO HILDEBRANDO CARRERA ABANTO  Cemento Pacasmayo Extraforte
# 1    ABELARDO HILDEBRANDO CARRERA ABANTO    Cemento Pacasmayo Fortimax
# ...
